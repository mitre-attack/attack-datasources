# %% [markdown]
# # ATT&CK® Data Sources & (Sub)Techniques Mapping
#
# ---------------------------------

# %% [markdown]
# * **Author**: Jose Luis Rodrigues - [@Cyb3rPandaH](https://twitter.com/Cyb3rPandaH)
# * **Organization**: [MITRE ATT&CK](https://attack.mitre.org/)
# * **Blog Reference**: [Defining ATT&CK Data Sources, Part I: Enhancing the Current State](https://medium.com/mitre-attack/defining-attack-data-sources-part-i-4c39e581454f)

# %% [markdown]
# ## Why this notebook?

# %% [markdown]
# The present notebook is intended to provide a list of the (sub)technqiues studied in order to identify data elements and relationships, and define data components related to ATT&CK data sources.

# %% [markdown]
# ## Where can you find the data?

# %% [markdown]
# All the data wil be keeped on the following **yaml** file: ***DataSources_Techniques_Mapping.yaml***

# %% [markdown]
# ## List of (sub)Techniques:

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('max_rows', None)

import yaml

# %%
with open('DataSources_Techniques_Mapping.yaml', 'r') as f:
    df = pd.json_normalize(yaml.load(f, Loader=yaml.FullLoader))

print("For the initial stage of this research ",df.shape[0]," (sub)techniques variations were used!!")

df[['tactic','technique','sub_technique','description']]
# Out:
# For the initial stage of this research  47  (sub)techniques variations were used!!
#                       tactic technique sub_technique  \
# 0                   [TA0002]     T1204     T1204.002
# 1                   [TA0005]     T1222     T1222.001
# 2                   [TA0005]     T1036     T1036.002
# 3                   [TA0005]     T1036     T1036.005
# 4                   [TA0011]     T1571          None
# 5                   [TA0005]     T1055     T1055.001
# 6                   [TA0011]     T1573     T1573.001
# 7                   [TA0002]     T1059     T1059.003
# 8                   [TA0002]     T1059     T1059.001
# 9                   [TA0007]     T1083          None
# 10                  [TA0009]     T1119          None
# 11                  [TA0009]     T1560     T1560.001
# 12                  [TA0009]     T1560     T1560.002
# 13                  [TA0009]     T1074     T1074.001
# 14                  [TA0011]     T1105          None
# ...

# %%
print("We are showing the first (sub)technique content as an example:")

df.iloc[0].tolist()
# Out:
# We are showing the first (sub)technique content as an example:
# [['TA0002'],
#  'T1204',
#  'T1204.002',
#  'User Execution - Malicious File',
#  ['https://github.com/OTRF/mordor/raw/master/datasets/large/apt29/day1/apt29_evals_day1_manual.zip'],
#  [{'data_source': 'Process',
#    'data_components': [{'component': 'process creation',
#      'relationships': [{'source_data_element': 'process',
#        'relationship': 'created',
#        'target_data_element': 'process'}]}]},
#   {'data_source': 'Windows registry',
#    'data_components': [{'component': 'Windows registry key modification',
#      'relationships': [{'source_data_element': 'process',
#        'relationship': 'modified',
#        'target_data_element': 'windows registry key value'}]}]}]]

# %% [markdown]
# # Thank you :)
