# %% [markdown]
# # ATT&CK® Data Sources Definition
#
# ---------------------------------

# %% [markdown]
# * **Author**: Jose Luis Rodriguez - [@Cyb3rPandaH](https://twitter.com/Cyb3rPandaH)
# * **Organization**: [MITRE ATT&CK](https://attack.mitre.org/)
# * **Blog Reference**:
#  - [Defining ATT&CK Data Sources, Part I: Enhancing the Current State](https://medium.com/mitre-attack/defining-attack-data-sources-part-i-4c39e581454f)
#  - [Defining ATT&CK Data Sources, Part II: Operationalizing the Methodology](https://medium.com/mitre-attack/defining-attack-data-sources-part-ii-1fc98738ba5b)

# %% [markdown]
# ## Goal & Scope

# %% [markdown]
# The present notebook is intended to provide basic examples of how can you merge **current data sources information** from **ATT&CK** and **new metadata** provided for **data source objects**. The examples provided consider (sub)techniques for the windows platform within the enterprise matrix.

# %% [markdown]
# ## Requeriments

# %% [markdown]
# * [Python 3](https://www.python.org)
# * [attackcti](https://pypi.org/project/attackcti/)
# * [pandas](https://pandas.pydata.org/)
# * [yaml](https://pyyaml.org/wiki/PyYAML)

# %% [markdown]
# ## First: Gathering current ATT&CK data sources metadata

# %% [markdown]
# * Importing python libraries and modules

# %%
# Importing library to interact with up to date ATT&CK content available in STIX format via public TAXII server
from attackcti import attack_client

# Importing library to manipulate data
import pandas as pd
from pandas import json_normalize

# %% [markdown]
# * Getting (sub)techniques

# %%
# Instantiating attack_client class
lift = attack_client()

# Collecting all techniques (Revoked and not revoked) for windows platform within the enterprise matrix
attck = lift.get_techniques_by_platform(name = 'Windows', stix_format = False)

# Removing revoked techniques
attck = lift.remove_revoked(attck)

# Generating a dataframe with information collected
attck = json_normalize(attck)

# Selecting columns
attck = attck[['tactic','technique_id','technique','data_sources']]

# Showing information collected
attck.head()
# Out:
#                                               tactic technique_id  \
# 0  [defense-evasion, persistence, command-and-con...    T1205.001
# 1                                  [defense-evasion]    T1564.006
# 2                                  [defense-evasion]    T1564.005
# 3  [persistence, privilege-escalation, defense-ev...    T1574.012
# 4                                  [defense-evasion]    T1480.001
#
#               technique                                       data_sources
# 0         Port Knocking          [Netflow/Enclave netflow, Packet capture]
# 1  Run Virtual Instance  [Packet capture, Host network interface, Windo...
# 2    Hidden File System                [File monitoring, Windows Registry]
# 3          COR_PROFILER  [Windows Registry, File monitoring, Process mo...
# 4  Environmental Keying                               [Process monitoring]

# %% [markdown]
# * Splitting data_sources field

# %%
attck = attck.explode('data_sources').reset_index(drop=True)
attck.head()
# Out:
#                                               tactic technique_id  \
# 0  [defense-evasion, persistence, command-and-con...    T1205.001
# 1  [defense-evasion, persistence, command-and-con...    T1205.001
# 2                                  [defense-evasion]    T1564.006
# 3                                  [defense-evasion]    T1564.006
# 4                                  [defense-evasion]    T1564.006
#
#               technique             data_sources
# 0         Port Knocking  Netflow/Enclave netflow
# 1         Port Knocking           Packet capture
# 2  Run Virtual Instance           Packet capture
# 3  Run Virtual Instance   Host network interface
# 4  Run Virtual Instance         Windows Registry

# %% [markdown]
# ## Second: Gathering new metadata of data source objects

# %% [markdown]
# * Importing python libraries

# %%
import yaml

# %% [markdown]
# * Getting metadata of data source objects

# %%
filePath = 'attack_data_sources.yaml'
yamlFile = open(filePath, 'r')
metadata = yaml.safe_load(yamlFile)
metadata = json_normalize(metadata)
yamlFile.close()
metadata.head()
# Out:
#          name                                         definition  \
# 0     Service  Information about software programs that run i...
# 1      Module  Information about portable executable files, s...
# 2  WMI object  Information about objects from the system clas...
# 3        File  Information about file objects that represent ...
# 4  Named pipe  Information about mechanisms that allow inter-...
#
#   collection_layers  platforms contributors  \
# 0            [host]  [Windows]     [ATT&CK]
# 1            [host]  [Windows]     [ATT&CK]
# 2            [host]  [Windows]     [ATT&CK]
# 3            [host]  [Windows]     [ATT&CK]
# 4            [host]  [Windows]     [ATT&CK]
#
#                                      data_components  \
# 0  [{'name': 'service creation', 'type': 'activit...
# 1  [{'name': 'module load', 'type': 'activity', '...
# 2  [{'name': 'wmi object context', 'type': 'infor...
# 3  [{'name': 'file creation', 'type': 'activity',...
# 4  [{'name': 'named pipe creation', 'relationship...
#
#                                           references
# 0  [https://docs.microsoft.com/en-us/dotnet/frame...
# 1  [https://docs.microsoft.com/en-us/windows/win3...
# 2  [https://docs.microsoft.com/en-us/windows/win3...
# 3  [https://docs.microsoft.com/en-us/windows/win3...
# 4  [https://docs.microsoft.com/en-us/windows/win3...

# %% [markdown]
# * Splitting data components content

# %%
# Splitting rows for data_components list
metadata = metadata.explode('data_components').reset_index(drop=True).rename(columns={'name':'data_sources'})

# Splitting columns for data_components dict
metadata = metadata['data_components'].apply(pd.Series).merge(metadata,left_index=True,right_index=True)\
.reset_index(drop=True).drop(['data_components'], axis = 1).rename(columns={'name':'data_components'})

# Splitting rows for relationships list
metadata = metadata.explode('relationships').reset_index(drop=True)

# Splitting columns for relationships dict
metadata = metadata['relationships'].apply(pd.Series).merge(metadata,left_index=True,right_index=True)\
.reset_index(drop=True).drop(['relationships'], axis = 1)

# Replacing Null values in target_data_element
metadata['target_data_element'].fillna(' ', inplace = True)

# Concatenating: Source + Relationship + Target
metadata['relationships'] = metadata['source_data_element']+'-'+metadata['relationship']+'-'+\
                            metadata['target_data_element']

# Deleting columns
dataSources = metadata.drop(['source_data_element','relationship','target_data_element'], axis = 1)

dataSources.head()
# Out:
#        data_components         type data_sources  \
# 0     service creation     activity      Service
# 1          module load     activity       Module
# 2          module load     activity       Module
# 3   wmi object context  information   WMI object
# 4  wmi object creation     activity   WMI object
#
#                                           definition collection_layers  \
# 0  Information about software programs that run i...            [host]
# 1  Information about portable executable files, s...            [host]
# 2  Information about portable executable files, s...            [host]
# 3  Information about objects from the system clas...            [host]
# 4  Information about objects from the system clas...            [host]
#
#    platforms contributors                                         references  \
# 0  [Windows]     [ATT&CK]  [https://docs.microsoft.com/en-us/dotnet/frame...
# 1  [Windows]     [ATT&CK]  [https://docs.microsoft.com/en-us/windows/win3...
# 2  [Windows]     [ATT&CK]  [https://docs.microsoft.com/en-us/windows/win3...
# 3  [Windows]     [ATT&CK]  [https://docs.microsoft.com/en-us/windows/win3...
# 4  [Windows]     [ATT&CK]  [https://docs.microsoft.com/en-us/windows/win3...
#
#                 relationships
# 0        user-created-service
# 1          process-loaded-dll
# 2   process-loaded-executable
# 3  wmi subscription-created-
# 4     user-created-wmi filter

# %% [markdown]
# ## Third: Mapping (sub)techniques to data components & relationships

# %% [markdown]
# * Getting new data sources names

# %% [markdown]
# According to the propossed methodoly, data sources names shoud make reference to the main data element they are related. Because of this, some of the current names might change. Therefore, in order to relate **(sub)techniques** to **data components**, we need update data sources names. We are providing a yaml file with data sources which names have been changed. We will use this file to update the content of our data frame.

# %%
namesPath = 'new_data_sources_names.yaml'
yamlNamesFile = open(namesPath, 'r')
names = yaml.safe_load(yamlNamesFile)
yamlNamesFile.close()
names = pd.DataFrame(list(names[0].items()), columns=['data_sources', 'new_names'])
names.head()
# Out:
#                data_sources        new_names
# 0  Sensor health and status       Sensor log
# 1             Access tokens     Access token
# 2           PowerShell logs   Powershell log
# 3            API monitoring              API
# 4          Application logs  Application log

# %% [markdown]
# * Updating data sources names

# %%
attck = pd.merge(attck, names, on = 'data_sources', how = 'left')
namesUpdate = attck['new_names'].fillna(attck['data_sources'])
attck = attck.drop(columns = ['new_names']).assign(data_sources = namesUpdate)
attck = attck.drop_duplicates(subset = ['technique_id','data_sources'])\
        .sort_values(by = ['technique'])\
        .reset_index(drop = True)
attck.head()
# Out:
#                                     tactic technique_id  \
# 0  [privilege-escalation, defense-evasion]        T1548
# 1  [privilege-escalation, defense-evasion]        T1548
# 2  [privilege-escalation, defense-evasion]        T1548
# 3  [privilege-escalation, defense-evasion]        T1548
# 4  [defense-evasion, privilege-escalation]        T1134
#
#                            technique      data_sources
# 0  Abuse Elevation Control Mechanism               API
# 1  Abuse Elevation Control Mechanism           Process
# 2  Abuse Elevation Control Mechanism              File
# 3  Abuse Elevation Control Mechanism  Windows registry
# 4          Access Token Manipulation           Process

# %% [markdown]
# * Mapping techniques to data components and relationships

# %%
techniques = pd.merge(attck, dataSources, on = 'data_sources', how = 'left')\
             [['tactic','technique_id','technique','data_sources','data_components','relationships']]

techniques.head()
# Out:
#                                     tactic technique_id  \
# 0  [privilege-escalation, defense-evasion]        T1548
# 1  [privilege-escalation, defense-evasion]        T1548
# 2  [privilege-escalation, defense-evasion]        T1548
# 3  [privilege-escalation, defense-evasion]        T1548
# 4  [privilege-escalation, defense-evasion]        T1548
#
#                            technique data_sources       data_components  \
# 0  Abuse Elevation Control Mechanism          API                   NaN
# 1  Abuse Elevation Control Mechanism      Process      process creation
# 2  Abuse Elevation Control Mechanism      Process      process creation
# 3  Abuse Elevation Control Mechanism      Process  process modification
# 4  Abuse Elevation Control Mechanism      Process        process access
#
#               relationships
# 0                       NaN
# 1      user-created-process
# 2   process-created-process
# 3  process-wrote to-process
# 4  process-accessed-process

# %% [markdown]
# ## Use case: T1112 Modify Registry

# %% [markdown]
# * What are the recommended data sources?

# %%
attck[attck['technique_id'] == 'T1112']
# Out:
#                 tactic technique_id        technique        data_sources
# 635  [defense-evasion]        T1112  Modify Registry             Process
# 636  [defense-evasion]        T1112  Modify Registry    Windows registry
# 637  [defense-evasion]        T1112  Modify Registry                File
# 638  [defense-evasion]        T1112  Modify Registry  Windows event logs

# %% [markdown]
# * What are the available data components and relationships?

# %%
techniques[techniques['technique_id'] == 'T1112']
# Out:
#                  tactic technique_id        technique        data_sources  \
# 3901  [defense-evasion]        T1112  Modify Registry             Process
# 3902  [defense-evasion]        T1112  Modify Registry             Process
# 3903  [defense-evasion]        T1112  Modify Registry             Process
# 3904  [defense-evasion]        T1112  Modify Registry             Process
# 3905  [defense-evasion]        T1112  Modify Registry             Process
# 3906  [defense-evasion]        T1112  Modify Registry             Process
# 3907  [defense-evasion]        T1112  Modify Registry             Process
# 3908  [defense-evasion]        T1112  Modify Registry             Process
# 3909  [defense-evasion]        T1112  Modify Registry             Process
# 3910  [defense-evasion]        T1112  Modify Registry             Process
# 3911  [defense-evasion]        T1112  Modify Registry             Process
# 3912  [defense-evasion]        T1112  Modify Registry             Process
# 3913  [defense-evasion]        T1112  Modify Registry             Process
# 3914  [defense-evasion]        T1112  Modify Registry             Process
# 3915  [defense-evasion]        T1112  Modify Registry             Process
# 3916  [defense-evasion]        T1112  Modify Registry             Process
# 3917  [defense-evasion]        T1112  Modify Registry             Process
# 3918  [defense-evasion]        T1112  Modify Registry    Windows registry
# 3919  [defense-evasion]        T1112  Modify Registry    Windows registry
# 3920  [defense-evasion]        T1112  Modify Registry    Windows registry
# 3921  [defense-evasion]        T1112  Modify Registry    Windows registry
# 3922  [defense-evasion]        T1112  Modify Registry    Windows registry
# 3923  [defense-evasion]        T1112  Modify Registry    Windows registry
# 3924  [defense-evasion]        T1112  Modify Registry    Windows registry
# 3925  [defense-evasion]        T1112  Modify Registry    Windows registry
# 3926  [defense-evasion]        T1112  Modify Registry    Windows registry
# 3927  [defense-evasion]        T1112  Modify Registry    Windows registry
# 3928  [defense-evasion]        T1112  Modify Registry    Windows registry
# 3929  [defense-evasion]        T1112  Modify Registry                File
# 3930  [defense-evasion]        T1112  Modify Registry                File
# 3931  [defense-evasion]        T1112  Modify Registry                File
# 3932  [defense-evasion]        T1112  Modify Registry                File
# 3933  [defense-evasion]        T1112  Modify Registry                File
# 3934  [defense-evasion]        T1112  Modify Registry                File
# 3935  [defense-evasion]        T1112  Modify Registry                File
# 3936  [defense-evasion]        T1112  Modify Registry  Windows event logs
#
#                         data_components  \
# 3901                   process creation
# 3902                   process creation
# 3903               process modification
# 3904                     process access
# 3905                     process access
# 3906         process network connection
# 3907         process network connection
# 3908         process network connection
# 3909         process network connection
# 3910         process network connection
# 3911         process network connection
# 3912         process network connection
# 3913         process network connection
# 3914         process network connection
# 3915         process network connection
# 3916         process network connection
# 3917         process network connection
# 3918      windows registry key creation
# 3919      windows registry key creation
# 3920      windows registry key deletion
# 3921      windows registry key deletion
# 3922  windows registry key modification
# 3923  windows registry key modification
# 3924  windows registry key modification
# 3925        Windows registry key access
# 3926        Windows registry key access
# 3927        Windows registry key access
# 3928        Windows registry key access
# 3929                      file creation
# 3930                      file deletion
# 3931                        file access
# 3932                        file access
# 3933                        file access
# 3934                        file access
# 3935                  file share access
# 3936                                NaN
#
#                                       relationships
# 3901                           user-created-process
# 3902                        process-created-process
# 3903                       process-wrote to-process
# 3904                       process-accessed-process
# 3905               process-requested access-process
# 3906                      process-connected to-port
# 3907                        process-connected to-ip
# 3908                      process-connected to-host
# 3909                    process-connected from-port
# 3910                      process-connected from-ip
# 3911                    process-connected from-host
# 3912                         user-connected to-port
# 3913                           user-connected to-ip
# 3914                         user-connected to-host
# 3915                       user-connected from-port
# 3916                         user-connected from-ip
# 3917                       user-connected from-host
# 3918            process-creted-windows registry key
# 3919      process-creted-windows registry key value
# 3920           process-deleted-windows registry key
# 3921     process-deleted-windows registry key value
# 3922          process-modified-windows registry key
# 3923    process-modified-windows registry key value
# 3924       user-modified-windows registry key value
# 3925          process-accessed-windows registry key
# 3926             user-accessed-windows registry key
# 3927  process-requested access-windows registry key
# 3928     user-requested access-windows registry key
# 3929                           process-created-file
# 3930                           process-deleted-file
# 3931                             user-accessed-file
# 3932                          process-accessed-file
# 3933                     user-requested access-file
# 3934                  process-requested access-file
# 3935                       user-accessed-file share
# 3936                                            NaN

# %% [markdown]
# # Thank you :)
