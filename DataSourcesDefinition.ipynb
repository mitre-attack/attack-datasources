# %% [markdown]
# # ATT&CK® Data Sources Definition
#
# ---------------------------------

# %% [markdown]
# * **Author**: Jose Luis Rodrigues - [@Cyb3rPandaH](https://twitter.com/Cyb3rPandaH)
# * **Organization**: [MITRE ATT&CK](https://attack.mitre.org/)
# * **Blog Reference**:
#  - [Defining ATT&CK Data Sources, Part I: Enhancing the Current State](https://medium.com/mitre-attack/defining-attack-data-sources-part-i-4c39e581454f) - [Defining ATT&CK Data Sources, Part II: Operationalizing the Methodology](https://medium.com/mitre-attack/defining-attack-data-sources-part-ii-1fc98738ba5b)

# %% [markdown]
# ## Goal & Scope

# %% [markdown]
# The present notebook is intended to provide basic examples of how can you merge **current data sources information** from **ATT&CK** and **new metadata** provided for **data source objects**. The examples provided consider (sub)techniques for the windows platform within the enterprise matrix.

# %% [markdown]
# ## Requeriments

# %% [markdown]
# * [Python 3](https://www.python.org)

# %% [markdown]
# * [attackcti](https://pypi.org/project/attackcti/)

# %% [markdown]
# * [pandas](https://pandas.pydata.org/)

# %% [markdown]
# * [yaml](https://pyyaml.org/wiki/PyYAML)

# %% [markdown]
# ## First: Gathering current ATT&CK data sources metadata

# %% [markdown]
# * Importing python libraries and modules

# %%
# Importing library to interact with up to date ATT&CK content available in STIX format via public TAXII server
from attackcti import attack_client

# Importing library to manipulate data
import pandas as pd
from pandas import json_normalize

# Do not truncate Pandas output
pd.set_option('display.max_colwidth', None)
pd.set_option('max_rows', None)

# %% [markdown]
# * Getting (sub)techniques

# %%
# Instantiating attack_client class
lift = attack_client()

# Collecting all techniques (Revoked and not revoked) for windows platform within the enterprise matrix
attck = lift.get_techniques_by_platform(name = 'Windows', stix_format = False)

# Removing revoked techniques
attck = lift.remove_revoked(attck)

# Generating a dataframe with information collected
attck = json_normalize(attck)

# Selecting columns
attck = attck[['tactic','technique_id','technique','data_sources']]

# Showing information collected
attck.head(3)
# Out:
#                                                 tactic technique_id  \
# 0  [defense-evasion, persistence, command-and-control]    T1205.001
# 1                                    [defense-evasion]    T1564.006
# 2                                    [defense-evasion]    T1564.005
#
#               technique  \
# 0         Port Knocking
# 1  Run Virtual Instance
# 2    Hidden File System
#
#                                                                                                                        data_sources
# 0                                                                                         [Netflow/Enclave netflow, Packet capture]
# 1  [Packet capture, Host network interface, Windows Registry, File monitoring, Process monitoring, Process command-line parameters]
# 2                                                                                               [File monitoring, Windows Registry]

# %% [markdown]
# * Splitting data_sources field

# %%
attck = attck['data_sources'].apply(pd.Series)\
.merge(attck, left_index = True, right_index = True)\
.drop(["data_sources"], axis = 1)\
.melt(id_vars = ['tactic','technique_id','technique'], value_name = "data_sources")\
.drop("variable", axis = 1)\
.dropna(subset=['data_sources'])
attck.head()
# Out:
#                                                  tactic technique_id  \
# 0   [defense-evasion, persistence, command-and-control]    T1205.001
# 1                                     [defense-evasion]    T1564.006
# 2                                     [defense-evasion]    T1564.005
# 3  [persistence, privilege-escalation, defense-evasion]    T1574.012
# 4                                     [defense-evasion]    T1480.001
#
#               technique             data_sources
# 0         Port Knocking  Netflow/Enclave netflow
# 1  Run Virtual Instance           Packet capture
# 2    Hidden File System          File monitoring
# 3          COR_PROFILER         Windows Registry
# 4  Environmental Keying       Process monitoring

# %% [markdown]
# ## Second: Gathering new metadata of data source objects

# %% [markdown]
# * Importing python libraries

# %%
import yaml

# %% [markdown]
# * Getting metadata of data source objects

# %%
filePath = 'attack_data_sources.yaml'
yamlFile = open(filePath, 'r')
metadata = yaml.safe_load(yamlFile)
metadata = json_normalize(metadata)
yamlFile.close()
metadata.head(3)
# Out:
#          name  \
# 0     Service
# 1      Module
# 2  WMI object
#
#                                                                                                                                        definition  \
# 0                                   Information about software programs that run in the background and typically start with the operating system.
# 1                  Information about portable executable files, such as a dll or an executable, consisting of one or more classes and interfaces.
# 2  Information about objects from the system classes, such as filters and consumers, that support Windows Management Instrumentation activitites.
#
#   collection_layers  platforms                   contributors  \
# 0            [host]  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
# 1            [host]  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
# 2            [host]  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          data_components  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [{'name': 'service creation', 'type': 'activity', 'relationships': [{'source_data_element': 'user', 'relationship': 'created', 'target_data_element': 'service'}]}]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [{'name': 'module load', 'type': 'activity', 'relationships': [{'source_data_element': 'process', 'relationship': 'loaded', 'target_data_element': 'dll'}, {'source_data_element': 'process', 'relationship': 'loaded', 'target_data_element': 'executable'}]}]
# 2  [{'name': 'wmi object context', 'type': 'information', 'relationships': [{'source_data_element': 'wmi subscription', 'relationship': 'created', 'target_data_element': None}]}, {'name': 'wmi object creation', 'type': 'activity', 'relationships': [{'source_data_element': 'user', 'relationship': 'created', 'target_data_element': 'wmi filter'}, {'source_data_element': 'user', 'relationship': 'created', 'target_data_element': 'wmi consumer'}, {'source_data_element': 'user', 'relationship': 'created', 'target_data_element': 'wmi subscription'}]}, {'name': 'wmi object deletion', 'type': 'activity', 'relationships': [{'source_data_element': 'user', 'relationship': 'deleted', 'target_data_element': 'wmi filter'}, {'source_data_element': 'user', 'relationship': 'deleted', 'target_data_element': 'wmi consumer'}, {'source_data_element': 'user', 'relationship': 'deleted', 'target_data_element': 'wmi subscription'}]}]
#
#                                                                                                                                                                                        references
# 0  [https://docs.microsoft.com/en-us/dotnet/framework/windows-services/introduction-to-windows-service-applications, https://www.linux.com/news/introduction-services-runlevels-and-rcd-scripts/]
# 1           [https://docs.microsoft.com/en-us/windows/win32/api/libloaderapi/nf-libloaderapi-loadlibrarya, https://docs.microsoft.com/en-us/dotnet/api/system.reflection.module?view=netcore-3.1]
# 2                                                                                                                      [https://docs.microsoft.com/en-us/windows/win32/wmisdk/wmi-system-classes]

# %% [markdown]
# * Mapping data sources to data components

# %%
dataComponentsNamesDict = {}
for i in range(0,len(metadata.index)):
    key = metadata.iloc[i,0]
    if key not in dataComponentsNamesDict:
            dataComponentsNamesDict[key] = []
    for dc in metadata['data_components'][i]:
            value = dc['name']
            dataComponentsNamesDict[key].append(value)

dataSources = pd.DataFrame(list(dataComponentsNamesDict.items()), columns=['data_sources', 'data_components'])
dataSources.head(3)
# Out:
#   data_sources                                                 data_components
# 0      Service                                              [service creation]
# 1       Module                                                   [module load]
# 2   WMI object  [wmi object context, wmi object creation, wmi object deletion]

# %% [markdown]
# * Mapping data components to relationships

# %% [markdown]
#    a) Dictionary format

# %%
dataComponentsDict = {}
for ds in metadata['data_components']:
    for dc in ds:
        key = dc['name']
        for rel in dc['relationships']:
            if key not in dataComponentsDict:
                dataComponentsDict[key] = []
            dataComponentsDict[key].append(rel)

dataComponents = pd.DataFrame(list(dataComponentsDict.items()), columns=['data_components', 'relationships'])
dataComponents.head(3)
# Out:
#       data_components  \
# 0    service creation
# 1         module load
# 2  wmi object context
#
#                                                                                                                                                                                      relationships
# 0                                                                                                   [{'source_data_element': 'user', 'relationship': 'created', 'target_data_element': 'service'}]
# 1  [{'source_data_element': 'process', 'relationship': 'loaded', 'target_data_element': 'dll'}, {'source_data_element': 'process', 'relationship': 'loaded', 'target_data_element': 'executable'}]
# 2                                                                                            [{'source_data_element': 'wmi subscription', 'relationship': 'created', 'target_data_element': None}]

# %% [markdown]
# b) Friendly format

# %%
dataComponentsDict = {}
for ds in metadata['data_components']:
    for dc in ds:
        key = dc['name']
        for rel in dc['relationships']:
            target = ' ' if rel['target_data_element'] is None else rel['target_data_element']
            x = str(rel['source_data_element']) + '-' + str(rel['relationship']) + '-' + target
            if key not in dataComponentsDict:
                dataComponentsDict[key] = []
            dataComponentsDict[key].append(x)

dataComponents = pd.DataFrame(list(dataComponentsDict.items()), columns=['data_components', 'relationships'])
dataComponents.head(3)
# Out:
#       data_components                                    relationships
# 0    service creation                           [user-created-service]
# 1         module load  [process-loaded-dll, process-loaded-executable]
# 2  wmi object context                     [wmi subscription-created- ]

# %% [markdown]
# ## Third: Mapping data components to relationships

# %% [markdown]
# * Getting new data sources names

# %% [markdown]
# According to the propossed methodoly, data sources names shoud make reference to the main data element they are related. Because of this, some of the current names might change. Therefore, in order to relate **(sub)techniques** to **data components**, we need update data sources names. We are providing a yaml file with data sources which names have been changed. We will use this file to update the content of our data frame.

# %%
namesPath = 'new_data_sources_names.yaml'
yamlNamesFile = open(namesPath, 'r')
names = yaml.safe_load(yamlNamesFile)
yamlNamesFile.close()
names = pd.DataFrame(list(names[0].items()), columns=['data_sources', 'new_names'])
names.head(3)
# Out:
#                data_sources       new_names
# 0  Sensor health and status      Sensor log
# 1             Access tokens    Access token
# 2           PowerShell logs  Powershell log

# %% [markdown]
# * Updating data sources names

# %%
attck = pd.merge(attck, names, on = 'data_sources', how = 'left')
namesUpdate = attck['new_names'].fillna(attck['data_sources'])
attck = attck.drop(columns = ['new_names']).assign(data_sources = namesUpdate)
attck = attck.drop_duplicates(subset = ['technique_id','data_sources'])\
        .sort_values(by = ['technique'])\
        .reset_index(drop = True)
attck.head()
# Out:
#                                     tactic technique_id  \
# 0  [privilege-escalation, defense-evasion]        T1548
# 1  [privilege-escalation, defense-evasion]        T1548
# 2  [privilege-escalation, defense-evasion]        T1548
# 3  [privilege-escalation, defense-evasion]        T1548
# 4  [defense-evasion, privilege-escalation]        T1134
#
#                            technique      data_sources
# 0  Abuse Elevation Control Mechanism              File
# 1  Abuse Elevation Control Mechanism               API
# 2  Abuse Elevation Control Mechanism  Windows registry
# 3  Abuse Elevation Control Mechanism           Process
# 4          Access Token Manipulation      Access token

# %% [markdown]
# * Mapping techniques to sub data sources

# %%
mappingDataComponents = pd.merge(attck, dataSources, on = 'data_sources', how = 'left')

mappingDataComponents = mappingDataComponents['data_components'].apply(pd.Series)\
    .merge(mappingDataComponents, left_index = True, right_index = True)\
    .drop(["data_components"], axis = 1)\
    .melt(id_vars = ['tactic','technique_id','technique','data_sources'], value_name = "data_components")\
    .drop("variable", axis = 1)\
    .drop_duplicates(subset = ['technique_id','data_sources','data_components'])\
    .dropna(subset=['data_components'])\
    .sort_values(by = ['technique'])\
    .reset_index(drop = True)

mappingDataComponents.head()

mappingDataComponents.head()
# Out:
#                                     tactic technique_id  \
# 0  [privilege-escalation, defense-evasion]        T1548
# 1  [privilege-escalation, defense-evasion]        T1548
# 2  [privilege-escalation, defense-evasion]        T1548
# 3  [privilege-escalation, defense-evasion]        T1548
# 4  [privilege-escalation, defense-evasion]        T1548
#
#                            technique      data_sources  \
# 0  Abuse Elevation Control Mechanism              File
# 1  Abuse Elevation Control Mechanism           Process
# 2  Abuse Elevation Control Mechanism           Process
# 3  Abuse Elevation Control Mechanism  Windows registry
# 4  Abuse Elevation Control Mechanism              File
#
#                data_components
# 0                file creation
# 1         process modification
# 2   process network connection
# 3  Windows registry key access
# 4                  file access

# %% [markdown]
# * Mapping techniques to relationships

# %%
mappingRelationships = pd.merge(mappingDataComponents, dataComponents, on = 'data_components', how = 'left')

mappingRelationships = mappingRelationships['relationships'].apply(pd.Series)\
    .merge(mappingRelationships, left_index = True, right_index = True)\
    .drop(["relationships"], axis = 1)\
    .melt(id_vars = ['tactic','technique_id','technique','data_sources','data_components'], value_name = "relationships")\
    .drop("variable", axis = 1)\
    .drop_duplicates(subset = ['technique_id','data_sources','data_components','relationships'])\
    .dropna(subset=['relationships'])\
    .sort_values(by = ['technique','data_sources','data_components'])\
    .reset_index(drop = True)

mappingRelationships.head()
# Out:
#                                     tactic technique_id  \
# 0  [privilege-escalation, defense-evasion]        T1548
# 1  [privilege-escalation, defense-evasion]        T1548
# 2  [privilege-escalation, defense-evasion]        T1548
# 3  [privilege-escalation, defense-evasion]        T1548
# 4  [privilege-escalation, defense-evasion]        T1548
#
#                            technique data_sources data_components  \
# 0  Abuse Elevation Control Mechanism         File     file access
# 1  Abuse Elevation Control Mechanism         File     file access
# 2  Abuse Elevation Control Mechanism         File     file access
# 3  Abuse Elevation Control Mechanism         File   file creation
# 4  Abuse Elevation Control Mechanism         File   file deletion
#
#                    relationships
# 0             user-accessed-file
# 1     user-requested access-file
# 2  process-requested access-file
# 3           process-created-file
# 4           process-deleted-file

# %% [markdown]
# ## Use case: T1112 Modify Registry

# %% [markdown]
# * What are the recommended data sources?

# %%
attck[attck['technique_id'] == 'T1112']
# Out:
#                 tactic technique_id        technique        data_sources
# 633  [defense-evasion]        T1112  Modify Registry                File
# 634  [defense-evasion]        T1112  Modify Registry  Windows event logs
# 635  [defense-evasion]        T1112  Modify Registry    Windows registry
# 636  [defense-evasion]        T1112  Modify Registry             Process

# %% [markdown]
# * What are the available data components and relationships?

# %%
mappingRelationships[mappingRelationships['technique_id'] == 'T1112']
# Out:
#                  tactic technique_id        technique      data_sources  \
# 3443  [defense-evasion]        T1112  Modify Registry              File
# 3444  [defense-evasion]        T1112  Modify Registry              File
# 3445  [defense-evasion]        T1112  Modify Registry              File
# 3446  [defense-evasion]        T1112  Modify Registry              File
# 3447  [defense-evasion]        T1112  Modify Registry              File
# 3448  [defense-evasion]        T1112  Modify Registry           Process
# 3449  [defense-evasion]        T1112  Modify Registry           Process
# 3450  [defense-evasion]        T1112  Modify Registry           Process
# 3451  [defense-evasion]        T1112  Modify Registry           Process
# 3452  [defense-evasion]        T1112  Modify Registry           Process
# 3453  [defense-evasion]        T1112  Modify Registry           Process
# 3454  [defense-evasion]        T1112  Modify Registry           Process
# 3455  [defense-evasion]        T1112  Modify Registry           Process
# 3456  [defense-evasion]        T1112  Modify Registry           Process
# 3457  [defense-evasion]        T1112  Modify Registry           Process
# 3458  [defense-evasion]        T1112  Modify Registry           Process
# 3459  [defense-evasion]        T1112  Modify Registry           Process
# 3460  [defense-evasion]        T1112  Modify Registry           Process
# 3461  [defense-evasion]        T1112  Modify Registry           Process
# 3462  [defense-evasion]        T1112  Modify Registry           Process
# 3463  [defense-evasion]        T1112  Modify Registry           Process
# 3464  [defense-evasion]        T1112  Modify Registry           Process
# 3465  [defense-evasion]        T1112  Modify Registry  Windows registry
# 3466  [defense-evasion]        T1112  Modify Registry  Windows registry
# 3467  [defense-evasion]        T1112  Modify Registry  Windows registry
# 3468  [defense-evasion]        T1112  Modify Registry  Windows registry
# 3469  [defense-evasion]        T1112  Modify Registry  Windows registry
# 3470  [defense-evasion]        T1112  Modify Registry  Windows registry
# 3471  [defense-evasion]        T1112  Modify Registry  Windows registry
# 3472  [defense-evasion]        T1112  Modify Registry  Windows registry
# 3473  [defense-evasion]        T1112  Modify Registry  Windows registry
# 3474  [defense-evasion]        T1112  Modify Registry  Windows registry
# 3475  [defense-evasion]        T1112  Modify Registry  Windows registry
#
#                         data_components  \
# 3443                        file access
# 3444                        file access
# 3445                        file access
# 3446                      file creation
# 3447                      file deletion
# 3448                     process access
# 3449                     process access
# 3450                   process creation
# 3451                   process creation
# 3452               process modification
# 3453         process network connection
# 3454         process network connection
# 3455         process network connection
# 3456         process network connection
# 3457         process network connection
# 3458         process network connection
# 3459         process network connection
# 3460         process network connection
# 3461         process network connection
# 3462         process network connection
# 3463         process network connection
# 3464         process network connection
# 3465        Windows registry key access
# 3466        Windows registry key access
# 3467        Windows registry key access
# 3468        Windows registry key access
# 3469      windows registry key creation
# 3470      windows registry key creation
# 3471      windows registry key deletion
# 3472      windows registry key deletion
# 3473  windows registry key modification
# 3474  windows registry key modification
# 3475  windows registry key modification
#
#                                       relationships
# 3443                             user-accessed-file
# 3444                     user-requested access-file
# 3445                  process-requested access-file
# 3446                           process-created-file
# 3447                           process-deleted-file
# 3448                       process-accessed-process
# 3449               process-requested access-process
# 3450                           user-created-process
# 3451                        process-created-process
# 3452                       process-wrote to-process
# 3453                      process-connected to-port
# 3454                        process-connected to-ip
# 3455                      process-connected to-host
# 3456                    process-connected from-port
# 3457                      process-connected from-ip
# 3458                    process-connected from-host
# 3459                         user-connected to-port
# 3460                           user-connected to-ip
# 3461                         user-connected to-host
# 3462                       user-connected from-port
# 3463                         user-connected from-ip
# 3464                       user-connected from-host
# 3465          process-accessed-windows registry key
# 3466             user-accessed-windows registry key
# 3467  process-requested access-windows registry key
# 3468     user-requested access-windows registry key
# 3469            process-creted-windows registry key
# 3470      process-creted-windows registry key value
# 3471           process-deleted-windows registry key
# 3472     process-deleted-windows registry key value
# 3473          process-modified-windows registry key
# 3474    process-modified-windows registry key value
# 3475       user-modified-windows registry key value

# %% [markdown]
# # Thank you :)
